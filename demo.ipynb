# %% [markdown]
# # Comments

# %%
# Single line  comments 

# comments : single comments

# %%
# multi line comments

#dajbdabdba,sbcf
#scbscb,sbc
#cbsjcbsjbcbskjbc

# %%
# docstrings comments
"""dfkjdfvkdbv
xcxzbvjxzv
xvxzjxhvcjzkvb
zsvhjzvjczs
hjvcsjsbc"""

# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### Heading 3

# %% [markdown]
# #### Heading 4

# %% [markdown]
# ##### Heading 5

# %% [markdown]
# ###### Heading 6

# %% [markdown]
# #  Comments
# - Single line comments
# - Multi Line Comments
# - Docstring Comments

# %% [markdown]
# - sbckzbvzbvkjdbvv

# %%
# explain : ""  and ''

# %%
a = 20 # integer value

# %%
# high level lang : abstract 
# low level lang  : direct acesss with hardware

# %%
# low level lang
int age = 20  # age

&age = # memory address

pointer = # lable of memory address:refrence

# %%
# high level lang : abstract 

book = "book_name"

# %%
varible = # interger, float, string, list,tuple,set,boolean

# %%
# two types
# global variable
# Local Variable

# %% [markdown]
# # varibale

# %%
# types two 
# 1 : Local Variable  : declare inside the function always : access inside the function always
# 2: Global Variable : declare outside the function always : access both outside and inside : for inside global

Course_name = "Full Stack Data Science Course"  # global variable


def course():
    std_name = "Sumit" # local variable
    global Course_name

# %%
# Print vs return


def addition():
    a = 10
    b = 20
    c = a+b
    print(c)

# %%
addition()
# Out:
# 30

# %% [markdown]
# # Dynamic Typing

# %%
int a = 10 # interger

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
A = 20

# %%
A = 30

# %%
strs = "sumit"

# %%
strs = "sunny sartale"

# %%
strs =strs.replace("sunny","sumit")

# %%
course = "Full stack Data Scinece"

def std_info():
    std_name = "Sumit"  # local 
    global course        # global variable 
    print(std_name,course)

# %%
std_info()
# Out:
# Sumit Full stack Data Scinece

# %%
a = 20

# %% [markdown]
# ###### Data Types
#
# - a
# - b

# %%
# 1: Number :

# two types : integer and float

# natural number : Interger
# decimal number : float


age = 20 # int

Height = 123.5 # float

print(type(Height))
# Out:
# <class 'float'>

# %%
 # addition 
    
a = 19
b = 20

c =a + b 
print(c)
# Out:
# 39

# %%
# substraction
a = 19
b = 20

c =a - b 
print(c)
# Out:
# -1

# %%
# Multi
a = 19
b = 20

c =a * b 
print(c)
# Out:
# 380

# %%
# division
a = 19
b = 20

c =a / b 
print(c)
# Out:
# 0.95

# %%
# Floor Division
a = 17
b = 2

c =a // b 
print(c)
# Out:
# 8

# %%
# module 
a = 20
b = 2

c =a % b  # check even or odd
print(c)
# Out:
# 0

# %%
# power


c = 2**3
c
# Out:
# 8

# %% [markdown]
# # 2. Comparison Operators

# %%
# Equal :  ==

a = 20
b = 20

print(a == b)
# Out:
# True

# %%
name = "sumit"

nick_name = "sumit"

print(name == nick_name)
# Out:
# True

# %%
# not equal  : !=

a = 20

b = 20
print(a != b)
# Out:
# False

# %%
# grater than : >


a = 20

b = 34

print(a > b)
# Out:
# False

# %%
# grater than : >


a = 20

b = 34

print(a > b or b > a)
# Out:
# True

# %%
a = 20

b = 34

print(a > b and b > a)
# Out:
# False

# %%
 print(0 < a < 30)
# Out:
# True

# %%
print(0 > a > 40)
# Out:
# False

# %%
a = 40

print(not(a > 30) and a < 50)
# Out:
# False

# %%
a = 20

print(a >= 20)
# Out:
# True

# %%
# take the value from user : 

a = int(input("Enter the value : "))
# Out:
# Enter the value : 1

# %%
# number is a immutable data type

# %%
A = 20

# %%
A = 30

# %% [markdown]
# # string

# %%
course =  "i'm sumit"

# %%
# String methods 

# method 1: upper() : all case convert into capitalize

lang = " i like python language "
lang =lang.upper()
lang
# Out:
# ' I LIKE PYTHON LANGUAGE '

# %%
# method 2: lower() : all case convert into lower form
lang =lang.lower()

# %%
# Method 3 : title() : all words of first case capitalize

lang.title()
# Out:
# ' I Like Python Language '

# %%
# method 4 : Capitalize()

name = "hi , i'm sumit sumit"

name.capitalize()
# Out:
# "Hi , i'm sumit sumit"

# %%
# seraching Methods 

# find()
name.find("s")
# Out:
# 9

# %%
#count()
name.count("Sumit")
# Out:
# 0

# %%
# Checking Methods (Boolean) 

# Method 1 : isalpha() : only check the charecter 

var = "sumit"

var.isalpha()
# Out:
# True

# %%
# method 2: isdigit() : check only digit 

var = "1233c"

var.isdigit()
# Out:
# False

# %%
# method 3: isalnum() : checl the letter and digit

var = "1234@sumit"
var.isalnum()
# Out:
# False

# %%
# method 4 : islower() : all letter lower

var = "12sui@t"

var.islower()
# Out:
# True

# %%
# replace method : replace()

# syntax = var.replace("old_text","new_text")

var = "Hi Everyone , Good Morning"

var=var.replace("Morning","Evening")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14268\23774812.py in <module>
#       5 var = "Hi Everyone , Good Morning"
#       6
# ----> 7 var=var.replace(Morning,"Evening")
#
# NameError: name 'Morning' is not defined

# %%
var
# Out:
# 'Hi Everyone , Good Morning'

# %%
var
# Out:
# 'Hi Everyone , Good Evening'

# %%
# Split method  : slice() : slice the text 

# index = two types

# 1 types : positive index   = 0 to infinity
# 2 Types : Negitive index   = -1 to -infinity

Name  = "Hi"

# syntax : var.split[start_index:end_index:mode]


Name[8:13]
# Out:
# ''

# %%
# split method 
Name.split()
# Out:
# ['Hi']

# %%
# strip method() : remove the white space form left right

Name = "  sumit        "
Name
# Out:
# '  sumit        '

# %%
Name.strip()
# Out:
# 'sumit'

# %%
Name.lstrip()
# Out:
# 'sumit        '

# %%
Name.rstrip()
# Out:
# '  sumit'

# %%
Name = "sumit"

# using slice i want to prit reverse mode

# expected o/t : timus

# %%
Name[::-1]
# Out:
# 'timus'

# %%
Name[::]
# Out:
# 'sumit'

# %%
Name[::-1]
# Out:
# 'timus'

# %%
# Method : Startswith / Endswith

Name = "Hi i am sumit"

Name.startswith("Hi")
# Out:
# True

# %%
Name.endswith("sumit")
# Out:
# True

# %%
# length : len()

Name = "Hi i am sumit"
len(Name)
# Out:
# 13

# %% [markdown]
# # List

# %%
list1 = ["parul", 22, "Bharat", 45.5, "vadodara", 99]

# %%
type(list1)
# Out:
# list

# %%
list1
# Out:
# ['parul', 22, 'Bharat', 45.5, 'vadodara', 99]

# %%
# method 1: append()

list1.append(3)

# %%
list1
# Out:
# ['parul', 22, 'Bharat', 45.5, 'vadodara', 99, 'sumit', 2, 2, 3]

# %%
list1.append("sunny")

# %%
# list1 : fruits

fruits = ["apple","banana","cherry","mango","orange"]

car = ["BMW","Thar","Tesla","tata","Auto"]

# %%
# add the multiple elemenst from the fruits 


fruits.append(car)

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'cherry',
#  'mango',
#  'orange',
#  ['BMW', 'Thar', 'Tesla', 'tata', 'Auto']]

# %%
# extend 

fruits.extend(car)

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'cherry',
#  'mango',
#  'orange',
#  'BMW',
#  'Thar',
#  'Tesla',
#  'tata',
#  'Auto']

# %%
# method 3 : insert() : add the value at specific position

listss = [1,2,2,34,3,4,5,2,6]

#insert the value

#listss.insert(2,40)

# %%
listss
# Out:
# [1, 2, 2, 34, 3, 4, 5, 2, 6]

# %%
# remove method : remove()

listss.remove(2)

# %%
listss
# Out:
# [1, 2, 34, 3, 4, 5, 2, 6]

# %%
# pop()

listss.pop(3)
# Out:
# 34

# %%
listss
# Out:
# [1, 2, 34, 3, 4, 5, 2, 6]

# %%
listss.clear()

# %%
listss
# Out:
# [1, 2, 2, 34, 3, 4, 5, 2, 6]

# %%
listss.count(30)
# Out:
# 0

# %%
listss.sort()

# %%
listss
# Out:
# [1, 2, 2, 2, 3, 4, 5, 6, 34]

# %%
listss.sort(reverse = True)

# %%
listss
# Out:
# [34, 6, 5, 4, 3, 2, 2, 2, 1]

# %%
 A  = input("Enter the value :")
# Out:
# Enter the value :233

# %%
type(A)
# Out:
# str

# %%
# dict

data = {
    "Car" : "Thar",
    "model" :2026,
    "color" :'white'
}

# %%
data
# Out:
# {'Car': 'Thar', 'model': 2026, 'color': 'white'}

# %%
data.values()
# Out:
# dict_values(['Thar', 2026, 'white'])

# %%
print(data.get("car"))
# Out:
# None

# %%
data.fromkeys(data.keys(),7)
# Out:
# {'Car': 7, 'model': 7, 'color': 7}

# %%
data.items()
# Out:
# dict_items([('Car', 'Thar'), ('model', 2026), ('color', 'white')])

# %%
# pop 

data.pop("Car")
# Out:
# 'Thar'

# %%
data
# Out:
# {'Car': 'Thar', 'model': 2026, 'color': 'white'}

# %%
# in the dict : pop always want the one arg :()

data.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20752\1441638404.py in <module>
# ----> 1 data.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
# update method 

data.update({"Car":"tesla"})

# %%
data
# Out:
# {'Car': 'tesla', 'model': 2026, 'color': 'white'}

# %%
# add the new item

data["price"] = 20000

# %%
data
# Out:
# {'Car': 'tesla', 'model': 2026, 'color': 'white', 'price': 20000}

# %%
# tuple 

tup1 = ("parul", 22, "Bharat", 45.5, "vadodara", 99,99)

# %%
tup1
# Out:
# ('parul', 22, 'Bharat', 45.5, 'vadodara', 99, 99)

# %%
type(tup1)
# Out:
# tuple

# %%
tup1.count(99)
# Out:
# 2

# %%
tup1[4]
# Out:
# 'vadodara'

# %%
len(tup1)
# Out:
# 7

# %%
tup1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20752\3559505791.py in <module>
# ----> 1 tup1
#
# NameError: name 'tup1' is not defined

# %%
# set
sets =  {1,2,3,4,54,5,6}

sets[]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20752\3966679664.py in <module>
#       2 sets =  {1,2,3,4,54,5,6}
#       3
# ----> 4 sets[2]
#
# TypeError: 'set' object is not subscriptable

# %%
sets = ()

# %%
# add the value in the set


new_set = {2,14,4,53,2,3}

new_set
# Out:
# {2, 3, 4, 14, 53}

# %%
new_set.add(22)

# %%
new_set
# Out:
# {2, 3, 4, 14, 22, 53}

# %%
sets = {1,5,2,7,"sumit",23,"sunny",34.2,4.32}

# %%
sets
# Out:
# {1, 2, 23, 34.2, 4.32, 5, 7, 'sumit', 'sunny'}

# %%
# update the sests : add the multiple value

sets.update([2,3,4,5])

# %%
sets
# Out:
# {1, 2, 23, 3, 34.2, 4, 4.32, 5, 7, 'sumit', 'sunny'}

# %%
# union : only return the unique values

set1 = {1,2,3,4,5}

set2 = {4,5,6,7,8}

set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
# intersection :  return the common value 

set1.intersection(set2)
# Out:
# {4, 5}

# %%
# difference ()

set1.difference(set2)
# Out:
# {1, 2, 3}

# %% [markdown]
# ## If Condition : statemensts

# %%
# syntax 
# if condition:
     # statements

# %%
A = 23

# chcek the Even ? 

if A % 2 == 0:
    print("Even Number")
    
else :
    print("Odd number")

# %%
# vote eligible 

Age = int(input("Enter the Age :"))

if Age >= 18:
    print("Eligible for vote")
else :
    print("Not Eligible for vote")
# Out:
# Enter the Age :52
# Eligible for vote

# %%
 # vowel string check
    
char  = str(input("Enter the name "))

vowel = ['A','E','I','O','U','a','e','i','o','u']

if Name not in vowel:
    print("Not Vowel")

else : 
    print("Yes Vowel")
# Out:
# Enter the name aiou
# Yes Vowel

# %%
# if value if even print the square of value 

A = 12

if A % 2 == 0:
    square =A **2
    print("Square of value  :",square)
else:
    print("Not Even number")
# Out:
# Square of value  : 144

# %%
# if elif else

Students_marks = int(input("Enter the Marks :"))


if Students_marks >= 85:
    print(" Excellent Beta")

elif Students_marks >= 75:
    print("Average Beta")
    
elif Students_marks >= 50:
    print("Good Beta")

elif Students_marks >= 35 :
    print(" Bach Gaya")
    
else : 
    print("Failed Tu tho Gaya")

# %%
# Value is positive or negitive 

A = 10

if A > 0:
    print("Positive Value")
    
else:
    print("Negitive Value")


# Write the program to check wheather number std is pass or failed  > 35

Std_mark = 23
    
if Std_mark > 35:
    print(" Passed !")
    
else:
    print(" Failed !")

# write to program to check weather a a number is divisible by 5 or nopt 

A  = 34

if  A / 5 == 0:
    print(" Division by 5")
    
else:
    print("Not Division by 5")

# write the program to check the temp condition : above 35 - hot ,20 to 35 - normal, below 20 - cold


temp = 56

if temp > 35:
    print("Hot Temp")
    
elif temp > 20 and temp < 35:
    print("Normal Temp")
    

else:
    print(" Cold Temp")
# Out:
# Positive Value
#  Failed !
# Not Division by 5
# Hot Temp

# %%
lists = []

salary 

credit score 

# u want check salary > 1000 and credit score is greater than 700

# then add the loan approved 

# not there add the not approved 

# add the loan approved or not approved

# %%
salary = int(input("Enter the Salary :"))

credit_score = int(input("Enter the Score :"))


# create the empty list 
lists = []


if salary > 5000 and credit_score > 700:
    lists.append("Loan Approved")
    
else:
    lists.append("Not Approved")

    
print(f"Loan Status : {lists}")
# Out:
# Enter the Salary :5800
# Enter the Score :740
# Loan Status : ['Loan Approved']

# %%
# string formating

Name = "Sumit"

Age  = 10

print(f"Hi , i'm {Name} and my {Age}")
# Out:
# Hi , i'm Sumit and my 10

# %%
Age = 19

has_id = True 

if Age >= 18:
      
else:
    print("Not Allowed")
# Out:
# Allowd

# %%
Marks  = 98

if Marks > 30 and Marks > 90:
    print("Pass and Gold medal")   
else:
    print("Failed")
# Out:
# Gold Medal

# %%
# if value > 0  : check the positive even either positive odd

#if not there say : neg value


value  = int(input("Enter the Value  :"))

if value  > 0:
    if value % 2 == 0:
        print("Positive Even Value ")
    else:
        print("Positive Odd Value ")
           
else:
    print("Negitive Value ")
# Out:
# Enter the Value  :7
# Positive Odd Value

# %%
a = 10
b = 20
c = 15

if a > b:
    if a > c:
        print("A is a Largest")
    else :
        print("C is a Largest")

# %%
Counter = 0

while Counter < 10:
    print("hello world")
    counter +=1

# %%
# list 

Age = [10,20,21,54,23,65,26,78,35]  

i = 0

while i < len(Age):
    if Age[i]  >=65:
        break
    else: 
        print("Allow")
        i +=1
# Out:
# Allow
# Allow
# Allow
# Allow
# Allow

# %%
# print all ages from a list using while loop ,but stop age is greater than  60
# print eligible fro ages above 18 but stop the loop if age is 65
# Create a program that Continuously print " Acces Granted " until the value 65 is found in the list

# %%
#Flow of While Loop

Start
   ↓
Check Condition
   ↓
True ? → Run Code
   ↓
Update Variable
   ↓
Go Back to Condition
   ↓
False ? → Stop

# %%
num = 1

# print the even number
while  num < 20 :
    if num % 2 == 0:
        print("Even Number")
    else:
        print("Odd Number")
        
    num +=1
# Out:
# Odd Number
# Even Number
# Odd Number
# Even Number
# Odd Number
# Even Number
# Odd Number
# Even Number
# Odd Number
# Even Number
# Odd Number
# Even Number
# Odd Number
# Even Number
# Odd Number
# Even Number
# Odd Number
# Even Number
# Odd Number

# %%
# Num 1

# which value division by 5

# Condition 50  : Stop condition

# %%
# for loop :

lists = [1,2,3,4,5,6,7]

for i in lists:
    if i % 2 == 0:
        print("Even Value")
        
    else:
        print("Odd Number")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
lists = [121,344,56,23445,567,12]

# which digit is grater than 3 : display the large number 

i = 2000

len(str(i))
# Out:
# 4

# %%
# for loop 


age  = [10,2,43,56,34,23,19,41,13,51]

for i in age:
    if i >=18 :
        print("Eligible for vote")
    else:
        print("Not Eligible for vote")
# Out:
# Not Eligible for vote
# Not Eligible for vote
# Eligible for vote
# Eligible for vote
# Eligible for vote
# Eligible for vote
# Eligible for vote
# Eligible for vote
# Not Eligible for vote
# Eligible for vote

# %%
palidrom = ["mam" ,"sumit","papa","naresh"]

for i in palidrom:
    reverse = i[::-1]
    if i == reverse:
        print("Palidrom")
    else:
        print("Not Palidrom")
# Out:
# Palidrom
# Not Palidrom
# Not Palidrom
# Not Palidrom

# %%
names  = ["sumit","neha","rjjjj","dinesh"]

vowel = "AEIOUaeiou"

for name  in names:
    found = False
    
    for char in name:
        if char in vowel:
            found = True
            break
            
    if found == True:
        print(f" {name} : Vowel")
    
    else:
        print(f"{name} : Not vowel")
# Out:
#  sumit : Vowel
#  neha : Vowel
# rjjjj : Not vowel
#  dinesh : Vowel

# %%
names  = ["sumit","neha","rjjjj","dinesh"]

for name in names:
    for char in name:
        print(char)
# Out:
# s
# u
# m
# i
# t
# n
# e
# h
# a
# r
# j
# j
# j
# j
# d
# i
# n
# e
# s
# h

# %%
name = " sumit"

# %%
names  = ["sumit","neha","rjjjj","dinesh"]



for i in names:
    if i[] in vowels:
        print(i, "- Vowel Name")
    else:
        print(i, "- Not Vowel")
# Out:
#   File "C:\Users\ssart\AppData\Local\Temp\ipykernel_6396\4206044653.py", line 6
#     if i[] in vowels:
#          ^
# SyntaxError: invalid syntax

# %%
names  = ["sumit","neha","rjjjj","dinesh"]



for i in names:
    
    i = i.lower()
    if ("a" in i or 
        "e" in i or 
        "i" in i or
        "u" in i or
        "o" in i ):
        print(f"{i} :vowel ")
    else:
        print(f"{i} : Not vowel")
# Out:
# sumit :vowel
# neha :vowel
# rjjjj : Not vowel
# dinesh :vowel

# %%
for i in range(0,10,2):
    if i % 2 == 0:
        print(f"Even Number : {i}")
    else:
        print(f"odd Number : {i}")
# Out:
# Even Number : 0
# Even Number : 2
# Even Number : 4
# Even Number : 6
# Even Number : 8

# %%
Name =  "Sumit"

for char in Name:
    print(char)
# Out:
# S
# u
# m
# i
# t

# %%
lists = [1,2,3,2,13,4,32,4,2,14,5,6]

ls  = []

for num in lists:
    if num not in ls:
        ls.append(num)

# %%
print(ls)
# Out:
# [1, 2, 3, 13, 4, 32, 14, 5, 6]

# %%
Dict = {"name":"Sumit","Age":10,"Salary":100}

for key ,value in Dict.items():
    print(f"Dict {key} and {value}")
# Out:
# Dict name and Sumit
# Dict Age and 10
# Dict Salary and 100

# %%
# enumarate 

lists = ["sumit","neha","rahul"]

for index,value in enumerate(lists):
    print(index,value)
# Out:
# 0 sumit
# 1 neha
# 2 rahul

# %%
lists = ["Sumit", "Rahul"]

for name in lists:
    for char in name:
        print(char)
# Out:
# S
# u
# m
# i
# t
# R
# a
# h
# u
# l

# %%
# break
lists = [1,2,3,4,5]

for num in lists:
    if num == 3:
        print()
        break
    print(num)
# Out:
# 1
# 2

# %%
# continue

lists = [1,2,3,4,5]

for num in lists:
    if num == 3:
        continue
    print(num)
# Out:
# 1
# 2
# 4
# 5

# %%
# pass


lists = [1,2,3,4,5]

for num in lists:
    pass

# %%
if 2 % 2 == 0:
    pass

# %%
name = ["Sumit","rahul"]

Age = [20,23]
# Out:
# Sumit rahul
# 20 23

# %%
for n,a in zip(name,Age):
    print(n,":",a)
# Out:
# Sumit : 20
# rahul : 23

# %%
# sysntax


try:
    
    # logic 
    # output
    
    
except Error name:
    print("Error Meassge")

# %%
# addition of two number

try:
    a = int(input("Enter the Number"))
    b = int(input("Enter the numbet"))
    
    result = a + b
    
    print(result)

except ValueError as e:
    print(e)
# Out:
# Enter the Number2.3
# invalid literal for int() with base 10: '2.3'

# %%
    a = int(input("Enter the Number"))
    b = int(input("Enter the numbet"))
    
    result = a + b
    
    print(result)
# Out:
# Enter the Number2.3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5056\2805409146.py in <module>
# ----> 1 a = int(input("Enter the Number"))
#       2 b = int(input("Enter the numbet"))
#       3
#       4 result = a + b
#       5
#
# ValueError: invalid literal for int() with base 10: '2.3'

# %%
# multi try except

try :
    num = int(input("Enter the value"))
    
    a = "sumit"
    b = 10
    result = b  + num
    
    
    print(result)
    
    
except ValueError:
    print(f"Please the check the {num}")
    

except ZeroDivisionError as e:
    print(f"Error : {e}")
    

except TypeError:
    print(f" Wrong value : {num}")
# Out:
# Enter the value10
# 20

# %%
a  = 10

b = "str"

a+ b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5056\1839686052.py in <module>
#       3 b = "str"
#       4
# ----> 5 a+ b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# catch multi error at time 


try:
    num = int(input("enter the value"))
    
    result = 100/num
    

    
except ValueError:
    print(f"Please the check the {num}")
    

except ZeroDivisionError as e:
    print(f"Error : {e}")
    
    
else :
    print(f"result : {result}")
# Out:
# enter the value2
# result : 50.0

# %%
# try except else


try:
    num = int(input("enter the value"))
    
    result = 100/num
    
    print(result)
    
except (ValueError,ZeroDivisionError):
    print("Check the value and non zero value")

# %%
# finally


try:
    num = int(input("enter the value"))
    
    result = 100/num
    
    print(result)
    
except ValueError as e:
    print(f"Error : {e}")
    
    
finally :
    print("Result Successfully Printed ")
# Out:
# enter the value2.3
# Error : invalid literal for int() with base 10: '2.3'
# Result Successfully Printed

# %%
# try except else finally


try:
    num = int(input("enter the value"))
    
    result = 100/num
    
    
    
except ValueError as e:
    print(f"Error : {e}")
    

except ZeroDivisionError:
    print("Please the non zero value")
    
    
else :
    print(f"Result : {result}")
    
    
finally :
    print("Result Successfully Printed ")

# %%
# read file and print the content

# error : FileNotFoundError

# add the content in the file : else


# print finally : File operation successfully Done !

# %%
try :
    file = open("data.txt","r")
    
    content =file.read()
    print(content)
    
except FileNotFoundError:
    print("File not Exit")
    

else:
    
    file = open("data.txt","a")
    
    file.write(" \n Hello Sumit")
    
    file.close()
    
    file = open("data.txt","r")
    
    content =file.read()
    print(content)
    
    
finally :
    print("File Successfully Done !")
# Out:
# 1
#  1
#  1
#  1Hello Sumit
# 1
#  1
#  1
#  1Hello Sumit
#  Hello Sumit
# File Successfully Done !

# %%
# exception 


try:
    num  = int(input("Enter the value"))
    result = 100/num
    
    print(result)
    
except Exception as e:
    print(f"Error : {e}")
# Out:
# Enter the value0
# Error : division by zero

# %%
int(input())
# Out:
# 2.3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13096\4025546921.py in <module>
# ----> 1 int(input())
#
# ValueError: invalid literal for int() with base 10: '2.3'

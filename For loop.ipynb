# %%
for iteration in place_name:
    # condition
       # statements

# %%
names = ["sumit","Sunny",'sartale'] 
 
for name in names: 
    for char in name:
        print(char)
# Out:
# s
# u
# m
# i
# t

# %%
lists = [20,30,40,50,60]

for num in lists:
    if num % 2 == 0:
        print("Even Number")
    else:
        print("Odd Number")
# Out:
# Even Number
# Even Number
# Even Number
# Even Number
# Even Number

# %%
# list comprehension

# syntax : only interation

# result = [ expression for i in place]

# %%
lists = [20,30,40,50,60]


result = [num for num in lists]

# %%
result
# Out:
# [20, 30, 40, 50, 60]

# %%
# iteration with condition if 

# syntax : result = [ expression for i in place if condition]

# %%
lists = [12,23,12,54,23,76,34]

result = [ (f"{num} :even") for num in lists if num % 2 == 0 ]

# %%
result
# Out:
# [' 12 :even', ' 12 :even', ' 54 :even', ' 76 :even', ' 34 :even']

# %%
num  = 23

res=num / 2 == 0
res
# Out:
# False

# %%
largest = [(f"largest Number : {num}" ) for num in lists if num >= 20 ]

# %%
largest
# Out:
# ['largest Number : 23',
#  'largest Number : 54',
#  'largest Number : 23',
#  'largest Number : 76',
#  'largest Number : 34']

# %%
# equal to 12 is there display value with masgg  value : true

lists = [12,23,12,54,23,76,34]

result = [(f"{num} : True")for num in lists if num == 12]

# %%
result
# Out:
# ['12 : True', '12 : True']

# %%
# palidrom

lists = [12,23,121,54,232,76,343]


result = [(f"{num} : palidrom") for num in lists if str(num) == str(num)[::-1]]

# %%
result
# Out:
# ['121 : palidrom', '232 : palidrom', '343 : palidrom']

# %%
lists = [12, 23, 121, 545, 23, 76, 34]

result = [f"palindrome {num}" for num in lists if str(num) == str(num)[::-1]]

print(result)
# Out:
# ['palindrome 121', 'palindrome 545']

# %%
# iteration : if else

# syntax = [ "if_answer"  if condition else "else_answer" for i in place]

# %%
lists = [12, 23, 121, 545, 23, 76, 34]

result = [ (f"Even Number: {num}") if num % 2 == 0 else (f"Odd Number: {num}")  for num in lists]

# %%
result
# Out:
# ['Even Number: 12',
#  'Odd Number: 23',
#  'Odd Number: 121',
#  'Odd Number: 545',
#  'Odd Number: 23',
#  'Even Number: 76',
#  'Even Number: 34']

# %%
resul = [ (f"Palidrom Number: {num}") if str(num) == str(num)[::-1] else (f"Not Palidrom Number: {num}")  for num in lists]

# %%
resul
# Out:
# ['Not Palidrom Number: 12',
#  'Not Palidrom Number: 23',
#  'Palidrom Number: 121',
#  'Palidrom Number: 545',
#  'Not Palidrom Number: 23',
#  'Not Palidrom Number: 76',
#  'Not Palidrom Number: 34']

# %%
string = ["Sumit" ,"RaJU" ,"NEHA","BhUMi"]


result = [ word.lower()  for word in string]

# %%
result
# Out:
# ['sumit', 'raju', 'neha', 'bhumi']

# %%
lists = [12, 23, 121, 545, 23, 76, 34]

# if value is even find the sqaured  either odd is there find the cube


# squred  = value ** 2
# cube   + value ** 3


result = [ (f"{num} :{num ** 2} : Even Number Sqaured") if num % 2 == 0   else (f"{num} :{num ** 3} : Odd Number Cube") for num in lists]

# %%
result
# Out:
# ['12 :144 : Even Number Sqaured',
#  '23 :12167 : Odd Number Cube',
#  '121 :1771561 : Odd Number Cube',
#  '545 :161878625 : Odd Number Cube',
#  '23 :12167 : Odd Number Cube',
#  '76 :5776 : Even Number Sqaured',
#  '34 :1156 : Even Number Sqaured']

# %%
# python identifier

age = [12,23,45,56,34,64,34,53]


def  a(a,b):
    print(a + b)

# %%
# function


# in build function

num  = 10
# calliing functiom
type(10)
# Out:
# int

# %%
num = [1,2,3,4,4,5,4]

len(num)
# Out:
# 7

# %%
id(5)
# Out:
# 1543405857200

# %%
abs(-2344)
# Out:
# 2344

# %%
num  = 234.4545667 

round(num,1)
# Out:
# 234.5

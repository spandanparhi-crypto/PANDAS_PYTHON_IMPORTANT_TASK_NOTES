# %%
from smartphone import Smartphone 


s2 = Smartphone("Iphone","17 pro","MID")
s2.show_all_details()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23032\1949271169.py in <module>
# ----> 1 from smartphone import Smartphone
#       2
#       3
#       4 s2 = Smartphone("Iphone","17 pro","MID")
#       5 s2.show_all_details()
#
# ModuleNotFoundError: No module named 'smartphone'

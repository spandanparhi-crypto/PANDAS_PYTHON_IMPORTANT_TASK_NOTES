# %%
# syntax filter 

# filter(function, iterable)

#function → returns True or False
#iterable → list, tuple, string, etc.
#Returns a filter object

# %%
# lambda args: expression

# %%
mult =lambda a,b: a*b

# %%
mult(10,20)
# Out:
# 200

# %%
two

# %%
sub(10,5)
# Out:
# 5

# %%
def sub(a,b):
    c = a - b
    return c

# %%
sub(10,5)
# Out:
# 5

# %%
# one arg

one_arg = lambda a : a - 10
one_arg(105)
# Out:
# 95

# %%
# two arg

# syntax : lambda arg:expression

two_arg = lambda a,x :a ** x
two_arg(3,3)
# Out:
# 27

# %%
# three arg

three_arg = lambda a,b,c : a * b * c
three_arg(1,2,3)
# Out:
# 6

# %%
# zero : no args

no_args = lambda : "hello everyone"
no_args()
# Out:
# 'hello everyone'

# %%
# conditional functionn
even_odd = lambda num: (f"{num} :Even Number") if num % 2 == 0 else (f"{num} :Odd Number")

even_odd(13)
# Out:
# '13 :Odd Number'

# %%
votes_check =lambda age :  (f"{age} :Allow Vote")if age >= 18 else  (f"{age} :Don't allow")

# %%
votes_check(4)
# Out:
# "4 :Don't allow"

# %%
lists = [1,2,2,3,4,5,6,7,8,9]

even_odd = tuple(map(lambda num:(f"{num} :Even Number") if num % 2 == 0 else (f"{num} :Odd Number"),lists))
even_odd
# Out:
# ('1 :Odd Number',
#  '2 :Even Number',
#  '2 :Even Number',
#  '3 :Odd Number',
#  '4 :Even Number',
#  '5 :Odd Number',
#  '6 :Even Number',
#  '7 :Odd Number',
#  '8 :Even Number',
#  '9 :Odd Number')

# %%
# task : 
names = ["suMit","raJesH","PraBhas"]


lower_case = map(lambda name : name.lower(),names)
list(lower_case)
# Out:
# ['sumit', 'rajesh', 'prabhas']

# %%
upper_case = map(lambda name : name.upper(),names)
list(upper_case)
# Out:
# ['SUMIT', 'RAJESH', 'PRABHAS']

# %%
title_case = map(lambda name : name.title(),names)
list(title_case)
# Out:
# ['Sumit', 'Rajesh', 'Prabhas']

# %%
ages = [20,30,45,56,76,47,28,98,59,86,34]

# age >= 45 "Old"
# age <= 45 "Young"

check_age =list(map(lambda age : "Old" if age >= 45 else "Young",ages))
check_age
# Out:
# ['Young',
#  'Young',
#  'Old',
#  'Old',
#  'Old',
#  'Old',
#  'Young',
#  'Old',
#  'Old',
#  'Old',
#  'Young']

# %%
numbers = [20,30,45,56,76,47,28,98,59,86,34]

check_even = filter(lambda num: num % 2 == 0 ,numbers)
list(check_even)
# Out:
# [20, 30, 56, 76, 28, 98, 86, 34]

# %%
ages = [20,30,45,56,76,47,28,98,59,86,34]


check_old = filter(lambda age: age >=45 ,numbers)
list(check_old)
# Out:
# [45, 56, 76, 47, 98, 59, 86]

# %%
# syntax of sorted value
#sorted(iterable, key=None, reverse=False)

names = ["Amit","John","Rajesh","Tom"]

sort_name = sorted(names, key = lambda x : len(x))

list(sort_name)
# Out:
# ['Tom', 'Amit', 'John', 'Rajesh']

# %%
ages = [20,35,67,45,67,87,48,96,23,43]

age_cat = map(lambda age : "old" if age > 45 else "young",ages)

# %%
age_old = filter(lambda age : age > 45,ages)

# %%
a=set(age_old)

# %%
a
# Out:
# {48, 67, 87, 96}

# %%
# sorted

sorted(ages)
# Out:
# [20, 23, 35, 43, 45, 48, 67, 67, 87, 96]

# %%
names = ["Amit","John","Rajesh","Tom"]

sorted(names ,key = lambda name : len(name))
# Out:
# ['Tom', 'Amit', 'John', 'Rajesh']

# %%
lists = [1,2,3,4,5,5,6]


# for loop  : 
#result =[i*2 for i in lists]
#result
# if condition ["if op" for i in place if condition]

#result = ["even" for i in lists if i % 2 == 0]
#result
# if else  ["if op" if condition  else "else op" for i in place

result = [ "even" if i % 2 == 0 else "odd" for i in lists ]
result
# Out:
# ['odd', 'even', 'odd', 'even', 'odd', 'odd', 'even']

# %%
# lambda  + list comprehension

numbers = [1, 2, 3, 4]

result  = [(lambda x : x **3)   (i) for i in numbers]
result
# Out:
# [1, 8, 27, 64]

# %%
result= [(lambda x: x ** 3) (i) for i in numbers]

result
# Out:
# [1, 8, 27, 64]

# %%
# file syntax

file=open("file_name","mode")

# %%
# method 1: read the file 

read_file = open("sumit.txt","r")

print(read_file.read())

# %%
# method 2 : write the file 

write_file = open("Data_Science.txt","w")

# write the content inside the empty file
write_file.write("Sumit ")

write_file.close()

# %%
# read the file : after create 
read_file = open("Data_Science.txt","r")

print(read_file.read())
# Out:
# Sumit

# %%
# method 3: append : add the text or data
 
append_file = open("Data_science.txt","a")

append_file.write(" Sartale")

append_file.close()

# %%
# read the file : after create 
append_file = open("Data_Science.txt","r")

print(append_file.read())
# Out:
# Sumit  Sartale

# %%
append_file = open("Data_science.txt","w")

append_file.write("/n Sartale")
append_file.write("/n Sartale")

append_file.close()

# %%
# read the file : after create 
append_file = open("Data_Science.txt","r")

print(append_file.read())
# Out:
# /n Sartale/n Sartale

# %% [markdown]
# # Type 1 : text.txt file

# %%
with open("File1.txt","w") as file:
    file.write("\n Hello")
    file.write("\n Hello")
    file.write("\n Hello")
    file.write("\n Hello")

    file.close()
    
print("File Successfully Created")
# Out:
# File Successfully Created

# %%
with open("File1.txt","r") as file:
    display = file.read()
    print(display)
# Out:
#  Hello
#  Hello
#  Hello
#  Hello

# %%
write_file = open("data.txt","w")

write_file.write("1")
write_file.write("\n 1")
write_file.write("\n 1")
write_file.write("\n 1")

write_file.close()

# %%
read_file = open("data.txt","r")

read_file.read()
# Out:
# '1\n 1\n 1\n 1'

# %%
file = open("File1.txt","a") 

file.write("\n Bye")
file.write("\n Bye")
file.write("\n Bye")
file.write("\n Bye")


    
print("File Successfully Append")
# Out:
# File Successfully Append

# %%
import pickle


student = {"name" : "sumit" ,"age" :20,"class" :"data_science"}


text = "hi"

student = bytes([1,2,3,4])

with open("model.bin","wb") as file:
    file.write(student)

# %%
with open("model.bin","rb") as file:
    binary_file =pickle.load(file)
    print(binary_file)
# Out:
# {'name': 'sumit', 'age': 20, 'class': 'data_science'}
